# %%
import mne
import numpy as  np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (8.0, 8.0)
plt.rcParams.update({'font.size': 12})

import warnings; warnings.simplefilter('ignore')

from sklearn.svm import SVC
from sklearn.model_selection import ShuffleSplit
from mne.decoding import CSP

# %%
filename="/Volumes/flashDrive/data/Ex10_Suj1_Run1-epo.fif"
epoch1 = mne.read_epochs(filename)
# Out:
# Reading /Volumes/flashDrive/data/Ex10_Suj1_Run1-epo.fif ...
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 61) active
#     Found the data of interest:
#         t =       0.00 ...    1400.00 ms
#         0 CTF compensation matrices available
# 280 matching events found
# Created an SSP operator (subspace dimension = 1)
# 280 matching events found
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated

# %%
epoch1.plot(n_channels=10,n_epochs=5)

# %%
Fp1 = epoch1._data[0] 
print Fp1.shape

Fz = epoch1._data[1]
print Fz.shape
# Out:
# (61, 1401)
# (61, 1401)

# %%
plt.plot(Fp1[0])

# %%
epoch1.plot(n_channels=1,n_epochs=5)

# %%
epoch1['scramble'].plot()

# %%
evoked = epoch1['scramble'].average()
print evoked
evoked.plot_joint()
# Out:
# <Evoked  |  comment : 'scramble', kind : average, time : [0.000000, 1.400000], n_epochs : 70, n_channels x n_times : 61 x 1401, ~803 kB>

# %%
 evoked
# Out:
# <Evoked  |  comment : 'scramble', kind : average, time : [0.000000, 1.400000], n_epochs : 70, n_channels x n_times : 61 x 1401, ~803 kB>

# %%
# Out:
# 0
